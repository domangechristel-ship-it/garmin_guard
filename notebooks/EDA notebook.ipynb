# %%
# %load_ext autoreload
# %autoreload 2

# %%
import pandas as pd

# %%
df = pd.read_csv('/home/christel/code/domangechristel-ship-it/Project/garmin_guard/data/processed/training_load_features.csv')

# %%
df.head()
# Out:
#   athlete_date  daily_tss  n_sessions  total_distance_m  total_duration_s  \
# 0   2023-04-02   8.178606         1.0            5900.3            2118.2
# 1   2023-04-03   0.000000         0.0               0.0               0.0
# 2   2023-04-04   0.000000         0.0               0.0               0.0
# 3   2023-04-05  15.938903         2.0           11146.5            3831.8
# 4   2023-04-06   0.000000         0.0               0.0               0.0
#
#    avg_hr  body_battery_delta  atl_7d  ctl_42d   tsb   acwr  has_session  \
# 0   139.0                 0.0    8.18     8.18  0.00  1.000            1
# 1     NaN                 NaN    6.13     7.80  1.67  0.786            0
# 2     NaN                 NaN    4.60     7.44  2.84  0.618            0
# 3   149.5                 0.0    7.44     7.83  0.39  0.950            1
# 4     NaN                 NaN    5.58     7.47  1.89  0.747            0
#
#    consecutive_training_days  load_spike_pct    acwr_zone
# ...

# %%
data = pd.read_csv('/home/christel/code/domangechristel-ship-it/Project/garmin_guard/data/processed/activities_normalized.csv')
data.head()
# Out:
#    activity_id                        name sport_type      location  \
# 0  10820369885  Villeurbanne Course à pied    RUNNING  Villeurbanne
# 1  10839296659  Villeurbanne Course à pied    RUNNING  Villeurbanne
# 2  10839297875          Lyon Course à pied    RUNNING          Lyon
# 3  10877047127  Villeurbanne Course à pied    RUNNING  Villeurbanne
# 4  10887998992  Villeurbanne Course à pied    RUNNING  Villeurbanne
#
#              start_utc          start_local athlete_date  distance_m  \
# 0  2023-04-02 13:24:17  2023-04-02 15:24:17   2023-04-02      5900.3
# 1  2023-04-05 08:35:15  2023-04-05 10:35:15   2023-04-05      5123.9
# 2  2023-04-05 09:19:21  2023-04-05 11:19:21   2023-04-05      6022.6
# 3  2023-04-10 18:31:33  2023-04-10 20:31:33   2023-04-10      6206.2
# 4  2023-04-12 08:47:44  2023-04-12 10:47:44   2023-04-12     15164.0
#
#    duration_s  moving_s  ...  hr_zone_6_s  lap_count     device_id  \
# 0      2118.2    2116.8  ...          0.0        6.0  3.970549e+09
# ...
